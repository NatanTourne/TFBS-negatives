# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
results_loc = "/data/home/natant/Negatives/Runs/Review_sane_model/Results/calibration_results.pkl"

# %%
results_df = pd.read_pickle(results_loc)

# %%
results_df
# Out:
#         TF  cross_val         neg_type cell_line  val_best_thresholds_MCC  \
# 0    NF-YA          0   dinucl_sampled   GM12878                     0.44
# 1    NF-YA          0        neighbors   GM12878                     0.48
# 2    NF-YA          0         celltype   GM12878                     0.57
# 3    NF-YA          0         shuffled   GM12878                     0.64
# 4    NF-YA          0  dinucl_shuffled   GM12878                     0.74
# ..     ...        ...              ...       ...                      ...
# 895    SRF          4   dinucl_sampled   GM12878                     0.69
# 896    SRF          4        neighbors   GM12878                     0.55
# 897    SRF          4         celltype   GM12878                     0.63
# 898    SRF          4         shuffled   GM12878                     0.57
# 899    SRF          4  dinucl_shuffled   GM12878                     0.54
#
#      val_best_thresholds_Precision  val_best_thresholds_Specificity  \
# 0                             0.99                             0.99
# 1                             0.98                             0.99
# 2                             0.99                             0.99
# 3                             0.98                             0.98
# 4                             0.99                             0.99
# ..                             ...                              ...
# 895                           0.99                             0.99
# 896                           0.99                             0.99
# 897                           0.99                             0.99
# 898                           0.99                             0.99
# 899                           0.99                             0.99
#
#      val_best_thresholds_Accuracy  val_best_thresholds_Recall  \
# 0                            0.44                        0.01
# 1                            0.48                        0.01
# 2                            0.57                        0.01
# 3                            0.37                        0.01
# 4                            0.71                        0.01
# ..                            ...                         ...
# 895                          0.56                        0.01
# 896                          0.55                        0.01
# 897                          0.56                        0.01
# 898                          0.53                        0.01
# 899                          0.53                        0.01
#
#     val_best_scores_MCC  ... test_scores_HQ_Specificity  \
# 0        tensor(0.7882)  ...             tensor(0.9904)
# 1        tensor(0.5711)  ...             tensor(0.9992)
# 2        tensor(0.6152)  ...             tensor(0.9995)
# 3        tensor(0.7539)  ...             tensor(0.9149)
# 4        tensor(0.6730)  ...             tensor(0.9899)
# ..                  ...  ...                        ...
# 895      tensor(0.6788)  ...             tensor(0.9777)
# 896      tensor(0.5114)  ...             tensor(0.9971)
# 897      tensor(0.4054)  ...             tensor(0.9990)
# 898      tensor(0.7063)  ...             tensor(0.6520)
# 899      tensor(0.5780)  ...             tensor(0.9940)
#
#     test_scores_HQ_Accuracy test_scores_HQ_Recall  \
# 0            tensor(0.8049)        tensor(0.9918)
# 1            tensor(0.8687)            tensor(1.)
# 2            tensor(0.9196)            tensor(1.)
# 3            tensor(0.4634)        tensor(0.9754)
# 4            tensor(0.9200)        tensor(0.9932)
# ..                      ...                   ...
# 895          tensor(0.7254)        tensor(0.9973)
# 896          tensor(0.7980)            tensor(1.)
# 897          tensor(0.8538)            tensor(1.)
# 898          tensor(0.2495)        tensor(0.9831)
# 899          tensor(0.7306)        tensor(0.9973)
#
#     test_scores_HQ_adjusted_AUROC  test_scores_HQ_adjusted_AvP  \
# 0                  tensor(0.9176)               tensor(0.2198)
# 1                  tensor(0.8679)               tensor(0.1094)
# 2                  tensor(0.8825)               tensor(0.1264)
# 3                  tensor(0.8168)               tensor(0.0740)
# 4                  tensor(0.8735)               tensor(0.1395)
# ..                            ...                          ...
# 895                tensor(0.8787)               tensor(0.2978)
# 896                tensor(0.8483)               tensor(0.2537)
# 897                tensor(0.8368)               tensor(0.2598)
# 898                tensor(0.5916)               tensor(0.0336)
# 899                tensor(0.8006)               tensor(0.2090)
#
#      test_scores_HQ_adjusted_MCC  test_scores_HQ_adjusted_Precision  \
# 0                 tensor(0.3105)                     tensor(0.2001)
# 1                 tensor(0.2088)                     tensor(0.2716)
# 2                 tensor(0.2537)                     tensor(0.2332)
# 3                 tensor(0.1478)                     tensor(0.0452)
# 4                 tensor(0.2716)                     tensor(0.1738)
# ..                           ...                                ...
# 895               tensor(0.3278)                     tensor(0.2991)
# 896               tensor(0.2961)                     tensor(0.5574)
# 897               tensor(0.3043)                     tensor(0.7215)
# 898               tensor(0.0412)                     tensor(0.0317)
# 899               tensor(0.2524)                     tensor(0.4058)
#
#      test_scores_HQ_adjusted_Specificity  test_scores_HQ_adjusted_Accuracy  \
# 0                         tensor(0.9904)                    tensor(0.9880)
# 1                         tensor(0.9992)                    tensor(0.9947)
# 2                         tensor(0.9995)                    tensor(0.9949)
# 3                         tensor(0.9423)                    tensor(0.9405)
# 4                         tensor(0.9899)                    tensor(0.9872)
# ..                                   ...                               ...
# 895                       tensor(0.9777)                    tensor(0.9643)
# 896                       tensor(0.9971)                    tensor(0.9775)
# 897                       tensor(0.9990)                    tensor(0.9783)
# 898                       tensor(0.6520)                    tensor(0.6479)
# 899                       tensor(0.9940)                    tensor(0.9749)
#
#     test_scores_HQ_adjusted_Recall
# 0                   tensor(0.9918)
# 1                       tensor(1.)
# 2                       tensor(1.)
# 3                   tensor(0.9754)
# 4                   tensor(0.9932)
# ..                             ...
# 895                 tensor(0.9973)
# 896                     tensor(1.)
# 897                     tensor(1.)
# 898                 tensor(0.9831)
# 899                 tensor(0.9973)
#
# [900 rows x 45 columns]

# %%
results_df.columns
# Out:
# Index(['TF', 'cross_val', 'neg_type', 'cell_line', 'val_best_thresholds_MCC',
#        'val_best_thresholds_Precision', 'val_best_thresholds_Specificity',
#        'val_best_thresholds_Accuracy', 'val_best_thresholds_Recall',
#        'val_best_scores_MCC', 'val_best_scores_Precision',
#        'val_best_scores_Specificity', 'val_best_scores_Accuracy',
#        'val_best_scores_Recall', 'val_best_thresholds_HQ_MCC',
#        'val_best_thresholds_HQ_Precision',
#        'val_best_thresholds_HQ_Specificity', 'val_best_thresholds_HQ_Accuracy',
#        'val_best_thresholds_HQ_Recall', 'val_best_scores_HQ_MCC',
#        'val_best_scores_HQ_Precision', 'val_best_scores_HQ_Specificity',
#        'val_best_scores_HQ_Accuracy', 'val_best_scores_HQ_Recall',
#        'test_scores_AUROC', 'test_scores_AvP', 'test_scores_MCC',
#        'test_scores_Precision', 'test_scores_Specificity',
#        'test_scores_Accuracy', 'test_scores_Recall', 'test_scores_HQ_AUROC',
#        'test_scores_HQ_AvP', 'test_scores_HQ_MCC', 'test_scores_HQ_Precision',
#        'test_scores_HQ_Specificity', 'test_scores_HQ_Accuracy',
#        'test_scores_HQ_Recall', 'test_scores_HQ_adjusted_AUROC',
#        'test_scores_HQ_adjusted_AvP', 'test_scores_HQ_adjusted_MCC',
#        'test_scores_HQ_adjusted_Precision',
#        'test_scores_HQ_adjusted_Specificity',
#        'test_scores_HQ_adjusted_Accuracy', 'test_scores_HQ_adjusted_Recall'],
#       dtype='object')

# %%
results_df["val_best_scores_HQ_Accuracy"]
# Out:
# 0      tensor(0.9438)
# 1      tensor(0.9439)
# 2      tensor(0.9440)
# 3      tensor(0.9438)
# 4      tensor(0.9434)
#             ...
# 895    tensor(0.9984)
# 896    tensor(0.9989)
# 897    tensor(0.9987)
# 898    tensor(0.9983)
# 899    tensor(0.9981)
# Name: val_best_scores_HQ_Accuracy, Length: 900, dtype: object

# %%
results_df["test_scores_HQ_adjusted_Accuracy"]
# Out:
# 0      tensor(0.9443)
# 1      tensor(0.9443)
# 2      tensor(0.9445)
# 3      tensor(0.9443)
# 4      tensor(0.9440)
#             ...
# 895    tensor(0.9982)
# 896    tensor(0.9987)
# 897    tensor(0.9985)
# 898    tensor(0.9983)
# 899    tensor(0.9979)
# Name: test_scores_HQ_adjusted_Accuracy, Length: 900, dtype: object

# %%
def plot_metric_comparison(df, metric='MCC'):
    """
    Plot comparison of a metric across normal, HQ, and HQ_adjusted versions on the same plot.
    
    Parameters:
    df: DataFrame containing the results
    metric: str, the metric to plot (e.g., 'MCC', 'Precision', 'AUROC')
    """
    # Extract the three versions of the metric
    normal_col = f'test_scores_{metric}'
    hq_col = f'test_scores_HQ_{metric}'
    hq_adjusted_col = f'test_scores_HQ_adjusted_{metric}'
    
    # Convert tensor values to float
    df_plot = df.copy()
    for col in [normal_col, hq_col, hq_adjusted_col]:
        df_plot[col] = df_plot[col].apply(lambda x: x.item() if isinstance(x, torch.Tensor) else x)
    
    # Create single figure
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Get unique neg_types for consistent ordering
    neg_types = df_plot['neg_type'].unique()
    
    # Prepare positions for boxplots
    positions_normal = []
    positions_hq = []
    positions_hq_adjusted = []
    
    width = 0.25
    for i, nt in enumerate(neg_types):
        base_pos = i * 1.0
        positions_normal.append(base_pos - width)
        positions_hq.append(base_pos)
        positions_hq_adjusted.append(base_pos + width)
    
    # Prepare data for boxplots
    data_normal = [df_plot[df_plot['neg_type'] == nt][normal_col].values for nt in neg_types]
    data_hq = [df_plot[df_plot['neg_type'] == nt][hq_col].values for nt in neg_types]
    data_hq_adjusted = [df_plot[df_plot['neg_type'] == nt][hq_adjusted_col].values for nt in neg_types]
    
    # Plot boxplots with different colors
    bp1 = ax.boxplot(data_normal, positions=positions_normal, widths=width, patch_artist=True, label='Normal')
    bp2 = ax.boxplot(data_hq, positions=positions_hq, widths=width, patch_artist=True, label='HQ')
    bp3 = ax.boxplot(data_hq_adjusted, positions=positions_hq_adjusted, widths=width, patch_artist=True, label='HQ Adjusted')
    
    # Color the boxplots
    for patch in bp1['boxes']:
        patch.set_facecolor('lightblue')
    for patch in bp2['boxes']:
        patch.set_facecolor('lightgreen')
    for patch in bp3['boxes']:
        patch.set_facecolor('lightcoral')
    
    # Set labels and title
    ax.set_xticks([i * 1.0 for i in range(len(neg_types))])
    ax.set_xticklabels(neg_types, rotation=45, ha='right')
    ax.set_xlabel('Negative Type')
    ax.set_ylabel(metric)
    ax.set_title(f'{metric} Comparison: Normal vs HQ vs HQ Adjusted')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
results_df
# Out:
#         TF  cross_val         neg_type cell_line  val_best_thresholds_MCC  \
# 0    TCF12          0   dinucl-sampled   GM12878                     0.22
# 1    TCF12          0        neighbors   GM12878                     0.51
# 2    TCF12          0         celltype   GM12878                     0.70
# 3    TCF12          0         shuffled   GM12878                     0.46
# 4    TCF12          0  dinucl-shuffled   GM12878                     0.43
# ..     ...        ...              ...       ...                      ...
# 895   ZZZ3          4   dinucl-sampled   GM12878                     0.55
# 896   ZZZ3          4        neighbors   GM12878                     0.51
# 897   ZZZ3          4         celltype   GM12878                     0.46
# 898   ZZZ3          4         shuffled   GM12878                     0.43
# 899   ZZZ3          4  dinucl-shuffled   GM12878                     0.55
#
#      val_best_thresholds_Precision  val_best_thresholds_Specificity  \
# 0                             0.38                             0.39
# 1                             0.96                             0.96
# 2                             0.98                             0.98
# 3                             0.56                             0.58
# 4                             0.99                             0.99
# ..                             ...                              ...
# 895                           0.65                             0.65
# 896                           0.93                             0.93
# 897                           0.86                             0.86
# 898                           0.43                             0.43
# 899                           0.57                             0.58
#
#      val_best_thresholds_Accuracy  val_best_thresholds_Recall  \
# 0                            0.15                        0.01
# 1                            0.50                        0.01
# 2                            0.69                        0.01
# 3                            0.39                        0.01
# 4                            0.42                        0.01
# ..                            ...                         ...
# 895                          0.55                        0.01
# 896                          0.51                        0.01
# 897                          0.46                        0.01
# 898                          0.42                        0.01
# 899                          0.54                        0.01
#
#     val_best_scores_MCC  ... test_scores_HQ_Specificity  \
# 0        tensor(0.5151)  ...                 tensor(1.)
# 1        tensor(0.4877)  ...             tensor(0.9999)
# 2        tensor(0.3740)  ...             tensor(0.9999)
# 3        tensor(0.7798)  ...                 tensor(1.)
# 4        tensor(0.5031)  ...             tensor(0.9995)
# ..                  ...  ...                        ...
# 895      tensor(0.5480)  ...             tensor(1.0000)
# 896      tensor(0.6065)  ...                 tensor(1.)
# 897      tensor(0.5540)  ...             tensor(1.0000)
# 898      tensor(0.6875)  ...             tensor(0.9950)
# 899      tensor(0.6192)  ...                 tensor(1.)
#
#     test_scores_HQ_Accuracy test_scores_HQ_Recall  \
# 0            tensor(0.4360)        tensor(0.9988)
# 1            tensor(0.7237)            tensor(1.)
# 2            tensor(0.7207)            tensor(1.)
# 3            tensor(0.2612)        tensor(0.9982)
# 4            tensor(0.6558)            tensor(1.)
# ..                      ...                   ...
# 895          tensor(0.7512)            tensor(1.)
# 896          tensor(0.9980)            tensor(1.)
# 897          tensor(0.9235)            tensor(1.)
# 898          tensor(0.9821)            tensor(1.)
# 899          tensor(0.7529)            tensor(1.)
#
#     test_scores_HQ_adjusted_AUROC  test_scores_HQ_adjusted_AvP  \
# 0                  tensor(0.7351)               tensor(0.1047)
# 1                  tensor(0.7801)               tensor(0.2176)
# 2                  tensor(0.7208)               tensor(0.1919)
# 3                  tensor(0.5605)               tensor(0.0604)
# 4                  tensor(0.7458)               tensor(0.1721)
# ..                            ...                          ...
# 895                tensor(0.8168)               tensor(0.3395)
# 896                tensor(0.8258)               tensor(0.5483)
# 897                tensor(0.8176)               tensor(0.4286)
# 898                tensor(0.7912)               tensor(0.4488)
# 899                tensor(0.7926)               tensor(0.2392)
#
#      test_scores_HQ_adjusted_MCC  test_scores_HQ_adjusted_Precision  \
# 0                 tensor(0.2040)                     tensor(0.1344)
# 1                 tensor(0.2436)                         tensor(1.)
# 2                 tensor(0.2098)                     tensor(0.6667)
# 3                 tensor(0.0750)                     tensor(0.0702)
# 4                 tensor(0.2125)                     tensor(0.3277)
# ..                           ...                                ...
# 895               tensor(0.4906)                     tensor(0.8182)
# 896               tensor(0.6529)                         tensor(1.)
# 897               tensor(0.5530)                         tensor(1.)
# 898               tensor(0.5419)                     tensor(0.6541)
# 899               tensor(0.3317)                     tensor(0.5213)
#
#      test_scores_HQ_adjusted_Specificity  test_scores_HQ_adjusted_Accuracy  \
# 0                             tensor(1.)                    tensor(0.9443)
# 1                             tensor(1.)                    tensor(0.9443)
# 2                         tensor(1.0000)                    tensor(0.9445)
# 3                             tensor(1.)                    tensor(0.9443)
# 4                         tensor(0.9995)                    tensor(0.9440)
# ..                                   ...                               ...
# 895                           tensor(1.)                    tensor(0.9982)
# 896                           tensor(1.)                    tensor(0.9987)
# 897                           tensor(1.)                    tensor(0.9985)
# 898                           tensor(1.)                    tensor(0.9983)
# 899                           tensor(1.)                    tensor(0.9979)
#
#     test_scores_HQ_adjusted_Recall
# 0                   tensor(0.9988)
# 1                       tensor(1.)
# 2                       tensor(1.)
# 3                   tensor(0.9982)
# 4                       tensor(1.)
# ..                             ...
# 895                     tensor(1.)
# 896                     tensor(1.)
# 897                     tensor(1.)
# 898                     tensor(1.)
# 899                     tensor(1.)
#
# [900 rows x 45 columns]

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='Accuracy')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='MCC')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='Precision')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='Recall')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='Specificity')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='AUROC')

# %%
# Plot MCC comparison across normal, HQ, and HQ_adjusted versions
plot_metric_comparison(results_df, metric='AvP')

# %%
# results_df.to_pickle(os.path.join(output_folder, "calibration_results.pkl"))

# %%
color_list = [
    "#ff595e", "#ff924c", "#ffca3a", "#c5ca30", "#8ac926",
    "#52a675", "#1982c4", "#4267ac", "#6a4c93", "#b5a6c9"
]

neg_mode_labels = {
    'dinucl_sampled': 'G-S',
    'dinucl_shuffled': 'DN-SH',
    'neighbors': 'NB-S',
    'shuffled': 'SH',
    'motif': "PWM",
    'celltype': 'CL',
    'HQ training': 'HQ'
}

# %%
results_df.neg_type.unique()
# Out:
# array(['dinucl_sampled', 'neighbors', 'celltype', 'shuffled',
#        'dinucl_shuffled'], dtype=object)

# %%
from matplotlib.patches import Patch
import seaborn as sns

# %%
# Define the metrics to plot
# (same list as before; these are the *base* metric names, not the HQ-adjusted ones)
metrics = [
    ('test_scores_AUROC', 'AUROC_value', 'auroc_metric'),
    ('test_scores_AvP', 'Average_Precision_value', 'Average_Precision_metric'),
    ('test_scores_Accuracy', 'Accuracy_value', 'Accuracy_metric'),
    ('test_scores_MCC', 'Matthews_Correlation_value', 'Matthews_Correlation_metric'),
    ('test_scores_Precision', 'Precision_value', 'Precision_metric'),
    ('test_scores_Specificity', 'Specificity_value', 'Specificity_metric'),
]

fig, axes = plt.subplots(3, 2, figsize=(8, 8))
axes = axes.flatten()

palette_standard = {
    'Standard': color_list[1],
    'HQ': color_list[5],
    'HQ adjusted': color_list[3],
}

for idx, (metric_name, value_col, metric_col) in enumerate(metrics):
    ax = axes[idx]

    # base metric short name, e.g. "AUROC"
    base = metric_name.replace("test_scores_", "")

    # column names in results_df
    std_col = metric_name                           # e.g. test_scores_AUROC
    hq_col = f"test_scores_HQ_{base}"               # e.g. test_scores_HQ_AUROC
    hq_adj_col = f"test_scores_HQ_adjusted_{base}"  # e.g. test_scores_HQ_adjusted_AUROC

    value_vars = []
    mapping = {}

    if std_col in results_df.columns:
        value_vars.append(std_col)
        mapping[std_col] = 'Standard'

    if hq_col in results_df.columns:
        value_vars.append(hq_col)
        mapping[hq_col] = 'HQ'

    if hq_adj_col in results_df.columns:
        value_vars.append(hq_adj_col)
        mapping[hq_adj_col] = 'HQ adjusted'

    # melt to long format
    melted_data = pd.melt(
        results_df.sort_values(by=['neg_type']),
        id_vars=['neg_type', "cell_line", 'TF'],
        value_vars=value_vars,
        var_name=metric_col,
        value_name=value_col
    )

    # convert tensors / objects to float
    melted_data[value_col] = melted_data[value_col].apply(
        lambda x: float(x.detach().cpu().numpy()) if hasattr(x, "detach") else float(x)
    )

    # map metric names to labels (Standard / HQ / HQ adjusted)
    melted_data[metric_col] = melted_data[metric_col].map(mapping)

    # map neg_mode labels
    melted_data = melted_data.rename(columns={"neg_type": "neg_mode"})
    melted_data['neg_mode_short'] = melted_data['neg_mode'].map(neg_mode_labels)

    # order categories by *HQ* performance if available, else by Standard
    order_source_label = 'HQ' if 'HQ' in melted_data[metric_col].unique() else 'Standard'
    order_source = melted_data[melted_data[metric_col] == order_source_label]

    mean_per_mode = (
        order_source
        .groupby("neg_mode_short")[value_col]
        .mean()
        .sort_values(ascending=True)
    )
    neg_mode_order_metric = mean_per_mode.index.tolist()

    melted_data["neg_mode_short"] = pd.Categorical(
        melted_data["neg_mode_short"],
        categories=neg_mode_order_metric,
        ordered=True
    )

    # Create boxplot with 3 hues where available
    sns.boxplot(
        data=melted_data,
        x='neg_mode_short',
        y=value_col,
        hue=metric_col,
        palette=palette_standard,
        dodge=True,
        ax=ax
    )

    ax.set_xlabel("Model")
    ax.set_ylabel(base.replace('_', ' '))
    ax.set_title(f"{base.replace('_', ' ')}")
    ax.set_ylim(0, 1)

    if ax.get_legend():
        ax.get_legend().remove()

# Shared legend: Standard, HQ, HQ adjusted
legend_handles = [
    Patch(facecolor=palette_standard['Standard'], edgecolor='black', label='Normal Test Set'),
    Patch(facecolor=palette_standard['HQ'], edgecolor='black', label='HQ Test Set'),
    Patch(facecolor=palette_standard['HQ adjusted'], edgecolor='black', label='HQ Adjusted Test Set'),
]
fig.legend(
    handles=legend_handles,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.05),
    ncol=3,
    frameon=True
)

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
results_df_2.columns
# Out:
# Index(['TF', 'cross_val', 'neg_type', 'cell_line', 'val_best_thresholds_MCC',
#        'val_best_thresholds_Precision', 'val_best_thresholds_Specificity',
#        'val_best_thresholds_Accuracy', 'val_best_thresholds_Recall',
#        'val_best_scores_MCC', 'val_best_scores_Precision',
#        'val_best_scores_Specificity', 'val_best_scores_Accuracy',
#        'val_best_scores_Recall', 'val_best_thresholds_HQ_MCC',
#        'val_best_thresholds_HQ_Precision',
#        'val_best_thresholds_HQ_Specificity', 'val_best_thresholds_HQ_Accuracy',
#        'val_best_thresholds_HQ_Recall', 'val_best_scores_HQ_MCC',
#        'val_best_scores_HQ_Precision', 'val_best_scores_HQ_Specificity',
#        'val_best_scores_HQ_Accuracy', 'val_best_scores_HQ_Recall',
#        'test_scores_AUROC', 'test_scores_AvP', 'test_scores_MCC',
#        'test_scores_Precision', 'test_scores_Specificity',
#        'test_scores_Accuracy', 'test_scores_Recall', 'test_scores_HQ_AUROC',
#        'test_scores_HQ_AvP', 'test_scores_HQ_MCC', 'test_scores_HQ_Precision',
#        'test_scores_HQ_Specificity', 'test_scores_HQ_Accuracy',
#        'test_scores_HQ_Recall', 'test_scores_HQ_adjusted_AUROC',
#        'test_scores_HQ_adjusted_AvP', 'test_scores_HQ_adjusted_MCC',
#        'test_scores_HQ_adjusted_Precision',
#        'test_scores_HQ_adjusted_Specificity',
#        'test_scores_HQ_adjusted_Accuracy', 'test_scores_HQ_adjusted_Recall'],
#       dtype='object')

# %%
# Load the second results dataframe
results_loc_2 = "/data/home/natant/Negatives/Runs/Review_calibration/calibration_results_take_2.pkl"
results_df_2 = pd.read_pickle(results_loc_2)
results_df_2["neg_type"] = results_df_2["neg_type"].replace({"dinucl-sampled": "dinucl_sampled", "dinucl-shuffled": "dinucl_shuffled"})

#
results_df_1 = results_df.copy()
results_df_1["model"] = "Sane"
results_df_2["model"] = "Simple"

# Concatenate both
combined_df = pd.concat([results_df_1, results_df_2], ignore_index=True)

# Define metrics to compare (only Standard + HQ)
metrics_compare = [
    ('test_scores_AUROC', 'AUROC_value', 'auroc_metric'),
    ('test_scores_AvP', 'Average_Precision_value', 'Average_Precision_metric'),
    ('test_scores_Accuracy', 'Accuracy_value', 'Accuracy_metric'),
    ('test_scores_MCC', 'MCC_value', 'MCC_metric'),
    ('test_scores_Precision', 'Precision_value', 'Precision_metric'),
    ('test_scores_Specificity', 'Specificity_value', 'Specificity_metric'),
]

fig2, axes2 = plt.subplots(3, 2, figsize=(8, 8))
axes2 = axes2.flatten()

palette_datasets = {
    'Sane-Normal': color_list[1],
    'Sane-HQ': color_list[5],
    'Simple-Normal': color_list[2],
    'Simple-HQ': color_list[7],
}

for idx, (metric_name, value_col, metric_col) in enumerate(metrics_compare):
    ax2 = axes2[idx]

    base = metric_name.replace("test_scores_", "")

    std_col = metric_name
    hq_col = f"test_scores_HQ_{base}"

    # Only keep rows where at least std_col or hq_col exist
    valid_cols = [c for c in [std_col, hq_col] if c in combined_df.columns]
    if not valid_cols:
        continue

    # Melt
    melted = pd.melt(
        combined_df.sort_values(by=['neg_type']),
        id_vars=['neg_type', 'cell_line', 'TF', 'model'],
        value_vars=valid_cols,
        var_name=metric_col,
        value_name=value_col
    )

    # Convert tensors to float
    melted[value_col] = melted[value_col].apply(
        lambda x: float(x.detach().cpu().numpy()) if hasattr(x, "detach") else float(x)
    )

    # Map metric name to "Normal"/"HQ"
    metric_map = {}
    if std_col in valid_cols:
        metric_map[std_col] = 'Normal'
    if hq_col in valid_cols:
        metric_map[hq_col] = 'HQ'
    melted[metric_col] = melted[metric_col].map(metric_map)

    # Build combined label: dataset + "-" + Normal/HQ
    melted['model_metric'] = melted['model'] + "-" + melted[metric_col]

    # Map neg_mode labels
    melted = melted.rename(columns={"neg_type": "neg_mode"})
    melted['neg_mode_short'] = melted['neg_mode'].map(neg_mode_labels)

    # Order categories by HQ of Original if available, else Normal of Original
    order_source = melted[
        (melted['model'] == 'Sane') &
        (melted[metric_col] == ('HQ' if 'HQ' in melted[metric_col].unique() else 'Normal'))
    ]
    mean_per_mode = (
        order_source
        .groupby("neg_mode_short")[value_col]
        .mean()
        .sort_values(ascending=True)
    )
    neg_mode_order_metric2 = mean_per_mode.index.tolist()

    melted["neg_mode_short"] = pd.Categorical(
        melted["neg_mode_short"],
        categories=neg_mode_order_metric2,
        ordered=True
    )

    sns.boxplot(
        data=melted,
        x='neg_mode_short',
        y=value_col,
        hue='model_metric',
        palette=palette_datasets,
        dodge=True,
        ax=ax2
    )

    ax2.set_xlabel("Model")
    ax2.set_ylabel(base.replace('_', ' '))
    ax2.set_title(f"{base.replace('_', ' ')}")
    ax2.set_ylim(0, 1)

    if ax2.get_legend():
        ax2.get_legend().remove()

# Shared legend for the new figure
legend_handles2 = [
    Patch(facecolor=palette_datasets['Sane-Normal'], edgecolor='black', label='Sane - Normal Test'),
    Patch(facecolor=palette_datasets['Sane-HQ'], edgecolor='black', label='Sane - HQ Test'),
    Patch(facecolor=palette_datasets['Simple-Normal'], edgecolor='black', label='Simple - Normal Test'),
    Patch(facecolor=palette_datasets['Simple-HQ'], edgecolor='black', label='Simple - HQ Test'),
]
fig2.legend(
    handles=legend_handles2,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.05),
    ncol=2,
    frameon=True
)

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()
