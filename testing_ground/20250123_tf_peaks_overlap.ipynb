# %%
input_folder = "/data/home/natant/Negatives/Data/Encode690/filtered_hg38_101bp"
metadata_file = "/data/home/natant/Negatives/Data/Encode690/filtered_hg38_101bp/metadata.csv"

# %%
import pandas as pd

metadata_df = pd.read_csv(metadata_file)
metadata_df
# Out:
#       project          lab               composite dataType   view     cell  \
# 0    wgEncode        Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks  GM12878
# 1    wgEncode        Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    HepG2
# 2    wgEncode        Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     K562
# 3    wgEncode  HudsonAlpha  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     A549
# 4    wgEncode  HudsonAlpha  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     A549
# ..        ...          ...                     ...      ...    ...      ...
# 142  wgEncode           UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks  HCT-116
# 143  wgEncode           UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks   HEK293
# 144  wgEncode           UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    HepG2
# 145  wgEncode           UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     K562
# 146  wgEncode           UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    MCF-7
#
#         treatment        antibody control             dataVersion  ...  \
# 0             NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 1             NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 2             NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 3    EtOH_0.02pct            ATF3     NaN  ENCODE Mar 2012 Freeze  ...
# 4       DEX_100nM  CREB1_(SC-240)     NaN  ENCODE Mar 2012 Freeze  ...
# ..            ...             ...     ...                     ...  ...
# 142           NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 143           NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 144           NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 145           NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
# 146           NaN            CTCF     std  ENCODE Mar 2012 Freeze  ...
#
#            type                            md5sum   size  \
# 0    narrowPeak  fef0af7fe1e724159e665085da53efb1   982K
# 1    narrowPeak  6f8ab32864e515e0362494a3a8df2b8e   892K
# 2    narrowPeak  919d1986bad2d03b4beb4a40a12f5bb2   1.2M
# 3    narrowPeak  04b555c96fac6ff5cd3ade02be4c9b66   168K
# 4    narrowPeak  4e04e30603901f81c80fb99c0394d11f   378K
# ..          ...                               ...    ...
# 142  narrowPeak  5353919b8dec58898d42391ed013ed3b  1006K
# 143  narrowPeak  85054a5025553ab029c7eb16c94dcbc4   1.1M
# 144  narrowPeak  3fdf2bfeeb9bf469510d615efec560ae   905K
# 145  narrowPeak  365af2fdea48c046dafad14b73f69b5d   850K
# 146  narrowPeak  5cef2172388928830a1151f06efdd161   1.2M
#
#                                               filename antibody_base  \
# 0    wgEncodeAwgTfbsBroadGm12878CtcfUniPk.narrowPea...          ctcf
# 1     wgEncodeAwgTfbsBroadHepg2CtcfUniPk.narrowPeak.gz          ctcf
# 2      wgEncodeAwgTfbsBroadK562CtcfUniPk.narrowPeak.gz          ctcf
# 3    wgEncodeAwgTfbsHaibA549Atf3V0422111Etoh02UniPk...          atf3
# 4    wgEncodeAwgTfbsHaibA549Creb1sc240V0416102Dex10...         creb1
# ..                                                 ...           ...
# 142     wgEncodeAwgTfbsUwHct116CtcfUniPk.narrowPeak.gz          ctcf
# 143     wgEncodeAwgTfbsUwHek293CtcfUniPk.narrowPeak.gz          ctcf
# 144      wgEncodeAwgTfbsUwHepg2CtcfUniPk.narrowPeak.gz          ctcf
# 145       wgEncodeAwgTfbsUwK562CtcfUniPk.narrowPeak.gz          ctcf
# 146       wgEncodeAwgTfbsUwMcf7CtcfUniPk.narrowPeak.gz          ctcf
#
#     cell_base maxatac_cell  df_cell maxatac_tf           df_tf
# 0     gm12878      GM12878  GM12878       CTCF            CTCF
# 1       hepg2        HepG2    HepG2       CTCF            CTCF
# 2        k562         K562     K562       CTCF            CTCF
# 3        a549         A549     A549       ATF3            ATF3
# 4        a549         A549     A549      CREB1  CREB1_(SC-240)
# ..        ...          ...      ...        ...             ...
# 142    hct116       HCT116  HCT-116       CTCF            CTCF
# 143    hek293       HEK293   HEK293       CTCF            CTCF
# 144     hepg2        HepG2    HepG2       CTCF            CTCF
# 145      k562         K562     K562       CTCF            CTCF
# 146      mcf7        MCF-7    MCF-7       CTCF            CTCF
#
# [147 rows x 24 columns]

# %%
import os
import pybedtools
from collections import defaultdict


# # Group files by cell type
cell_groups = metadata_df.groupby('cell')['filename'].apply(list).to_dict()

# Function to load narrowPeak files and convert to BedTool objects
def load_peaks(file_list, input_folder):
    bedtools_list = []
    for file in file_list:
        file_path = os.path.join(input_folder, file.rstrip('.gz'))
        bedtools_list.append(pybedtools.BedTool(file_path))
    return bedtools_list

# Function to merge peaks and annotate with TFs
def merge_peaks_with_tfs(bedtools_list, tf_list):
    merged_peaks = bedtools_list[0].cat(*bedtools_list[1:], postmerge=False).sort().merge(c=4, o='distinct')
    annotated_peaks = []
    for peak in merged_peaks:
        overlapping_tfs = set()
        for bedtool, tf in zip(bedtools_list, tf_list):
            if bedtool.any_hits(peak):
                overlapping_tfs.add(tf)
        peak.fields.append(','.join(overlapping_tfs))
        annotated_peaks.append(peak)
    return pybedtools.BedTool(annotated_peaks)

# Process each cell type group
merged_results = defaultdict(list)
for cell, files in cell_groups.items():
    bedtools_list = load_peaks(files, input_folder)
    tf_list = metadata_df[metadata_df['filename'].isin(files)]['antibody_base'].tolist()
    merged_peaks = merge_peaks_with_tfs(bedtools_list, tf_list)
    merged_results[cell] = merged_peaks

# Convert merged results to DataFrame
merged_peaks_list = []
for cell, peaks in merged_results.items():
    for peak in peaks:
        merged_peaks_list.append({
            'cell': cell,
            'chrom': peak.chrom,
            'start': peak.start,
            'end': peak.end,
            'tfs': peak.fields[-1]
        })

merged_peaks_df = pd.DataFrame(merged_peaks_list)
merged_peaks_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 31
#      29     bedtools_list = load_peaks(files, input_folder)
#      30     tf_list = metadata_df[metadata_df['filename'].isin(files)]['antibody_base'].tolist()
# ---> 31     merged_peaks = merge_peaks_with_tfs(bedtools_list, tf_list)
#      32     merged_results[cell] = merged_peaks
#      34 # Convert merged results to DataFrame
#
# Cell In[17], line 20, in merge_peaks_with_tfs(bedtools_list, tf_list)
#      18 overlapping_tfs = set()
#      19 for bedtool, tf in zip(bedtools_list, tf_list):
# ---> 20     if bedtool.any_hits(peak):
#      21         overlapping_tfs.add(tf)
#      22 peak.fields.append(','.join(overlapping_tfs))
#
# File /opt/Anaconda3/envs/plmbind4/lib/python3.11/site-packages/pybedtools/bedtool.py:1746, in BedTool.any_hits(self, interval, same_strand, overlap)
#    1744     fn = self.bam_to_bed().fn
#    1745 interval_file = pybedtools.IntervalFile(fn)
# -> 1746 return interval_file.any_hits(interval, same_strand, overlap)
#
# KeyboardInterrupt:

# %%
# import os
# import pybedtools
# from collections import defaultdict


# # Group files by cell type
# cell_groups = metadata_df.groupby('cell')['filename'].apply(list).to_dict()

# # Function to load narrowPeak files and convert to BedTool objects
# def load_peaks(file_list, input_folder):
#     bedtools_list = []
#     for file in file_list:
#         file_path = os.path.join(input_folder, file.rstrip('.gz'))
#         bedtools_list.append(pybedtools.BedTool(file_path))
#     return bedtools_list

# # Function to calculate overlaps and unique peaks
# def calculate_overlaps(bedtools_list):
#     if len(bedtools_list) < 2:
#         return 0, 0, 0  # Not enough files to compare

#     # Calculate intersections
#     intersection = bedtools_list[0]
#     for bedtool in bedtools_list[1:]:
#         intersection = intersection.intersect(bedtool, u=True)

#     # Calculate unique peaks
#     unique_peaks = sum(len(bedtool) for bedtool in bedtools_list) - len(intersection)

#     # Calculate percentage of overlapping peaks
#     total_peaks = sum(len(bedtool) for bedtool in bedtools_list)
#     overlap_percentage = (len(intersection) / total_peaks) * 100

#     return overlap_percentage, unique_peaks, len(intersection)

# # Process each cell type group
# results = defaultdict(dict)
# for cell, files in cell_groups.items():
#     bedtools_list = load_peaks(files, input_folder)
#     overlap_percentage, unique_peaks, len_intersection = calculate_overlaps(bedtools_list)
#     results[cell]['overlap_percentage'] = overlap_percentage
#     results[cell]['unique_peaks'] = unique_peaks
#     results[cell]['overlapping_peaks'] = len_intersection

# # Calculate the number of TFs and list them for each cell type
# for cell, files in cell_groups.items():
#     tf_set = set(metadata_df[metadata_df['cell'] == cell]['antibody_base'])
#     results[cell]['num_tfs'] = len(tf_set)
#     results[cell]['tfs'] = list(tf_set)
#     # results[cell]['total_peaks'] = sum(len(pybedtools.BedTool(os.path.join(input_folder, file.rstrip('.gz')))) for file in files)
#     # results[cell]['overlapping_peaks'] = len(pybedtools.BedTool(os.path.join(input_folder, files[0].rstrip('.gz'))).intersect(bedtools_list[0], u=True))

# results_df = pd.DataFrame.from_dict(results, orient='index')
# results_df


# WRONG!
