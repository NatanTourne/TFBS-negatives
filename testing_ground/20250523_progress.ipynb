# %%
import pandas as pd
import os
import time
from tqdm import tqdm
import datetime
import argparse


output_folder = "/data/home/natant/Negatives/Runs/debug"
file_path = os.path.join(output_folder, "model_combinations.csv")
model_combinations_df = pd.read_csv(file_path)

correct_neg_mode_names = {
    "dinucl_shuffled": "dinucl-shuffled",
    "dinucl_sampled": "dinucl-sampled"
}
correct_neg_mode_names_reverse = {v: k for k, v in correct_neg_mode_names.items()}

def get_current_df():
    ckpt_files = [f for f in os.listdir(output_folder) if f.endswith('.ckpt')]
    updated_ckpt_files = [
        f.replace(old, new) if old in f else f
        for f in ckpt_files
        for old, new in correct_neg_mode_names.items()
        if old in f or all(k not in f for k in correct_neg_mode_names)
    ]
    # Remove duplicates if a file matches multiple keys
    updated_ckpt_files = list(dict.fromkeys(updated_ckpt_files))
    data = []
    for file in updated_ckpt_files:
        celltype = file.split("_")[0]
        TF = "_".join(file.split("_")[1:-8])
        neg_mode = file.split("_")[-8]
        CV = file.split("_")[-7]
        date = file.split("_")[-6]
        time = file.split("_")[-5]
        data.append({"Cell Type": celltype, "TF": TF, "Negative Sampling Mode": neg_mode, "Cross Val Fold": CV, "Date": date, "Time": time})
    return pd.DataFrame(data)

# %%
ckpt_files = [f for f in os.listdir(output_folder) if f.endswith('.ckpt')]
updated_ckpt_files = [
    f.replace(old, new) if old in f else f
    for f in ckpt_files
    for old, new in correct_neg_mode_names.items()
    if old in f or all(k not in f for k in correct_neg_mode_names)
]
# Remove duplicates if a file matches multiple keys
updated_ckpt_files = list(dict.fromkeys(updated_ckpt_files))

# %%
updated_ckpt_files
# Out:
# ['MCF-7_CTCF_dinucl-sampled_CV-3_20250523_09:56_epoch=13_val_loss=0.45_AUROC=0.87.ckpt',
#  'GM12878_CTCF_neighbors_CV-4_20250523_12:46_epoch=14_val_loss=0.33_AUROC=0.97.ckpt',
#  'GM12878_YY1_(SC-281)_shuffled_CV-0_20250523_13:05_epoch=06_val_loss=0.43_AUROC=0.93.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-2_20250523_10:58_epoch=24_val_loss=0.67_AUROC=0.67.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-3_20250523_10:36_epoch=17_val_loss=0.69_AUROC=0.68.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-0_20250523_10:32_epoch=19_val_loss=0.67_AUROC=0.69.ckpt',
#  'MCF-7_CTCF_dinucl-sampled_CV-4_20250523_10:01_epoch=14_val_loss=0.55_AUROC=0.82.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-1_20250523_10:02_epoch=14_val_loss=0.52_AUROC=0.82.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-0_20250523_12:59_epoch=09_val_loss=0.53_AUROC=0.81.ckpt',
#  'MCF-7_CTCF_neighbors_CV-5_20250523_10:23_epoch=11_val_loss=0.47_AUROC=0.88.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-3_20250523_11:05_epoch=23_val_loss=0.70_AUROC=0.70.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-4_20250523_11:05_epoch=14_val_loss=0.64_AUROC=0.69.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-5_20250523_11:14_epoch=45_val_loss=0.24_AUROC=0.97.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-1_20250523_12:52_epoch=12_val_loss=0.41_AUROC=0.88.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-3_20250523_10:51_epoch=20_val_loss=0.68_AUROC=0.62.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-4_20250523_12:04_epoch=08_val_loss=0.40_AUROC=0.96.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-4_20250523_11:40_epoch=27_val_loss=0.28_AUROC=0.95.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-3_20250523_10:41_epoch=37_val_loss=0.31_AUROC=0.95.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-5_20250523_11:42_epoch=47_val_loss=0.44_AUROC=0.95.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-4_20250523_11:48_epoch=17_val_loss=0.67_AUROC=0.64.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-1_20250523_11:36_epoch=23_val_loss=0.44_AUROC=0.94.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-0_20250523_11:29_epoch=22_val_loss=0.70_AUROC=0.66.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-1_20250523_12:59_epoch=10_val_loss=0.59_AUROC=0.79.ckpt',
#  'MCF-7_CTCF_neighbors_CV-4_20250523_10:21_epoch=11_val_loss=0.54_AUROC=0.85.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-2_20250523_13:00_epoch=08_val_loss=0.55_AUROC=0.83.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-3_20250523_12:55_epoch=10_val_loss=0.43_AUROC=0.87.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-0_20250523_10:46_epoch=18_val_loss=0.64_AUROC=0.69.ckpt',
#  'GM12878_CTCF_shuffled_CV-5_20250523_12:18_epoch=89_val_loss=0.32_AUROC=0.99.ckpt',
#  'MCF-7_CTCF_shuffled_CV-4_20250523_10:14_epoch=66_val_loss=0.63_AUROC=0.96.ckpt',
#  'GM12878_CTCF_shuffled_CV-1_20250523_12:09_epoch=31_val_loss=0.34_AUROC=0.98.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-5_20250523_10:06_epoch=26_val_loss=0.62_AUROC=0.75.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-0_20250523_11:59_epoch=12_val_loss=0.27_AUROC=0.96.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-5_20250523_13:05_epoch=07_val_loss=0.50_AUROC=0.85.ckpt',
#  'MCF-7_CTCF_neighbors_CV-2_20250523_10:19_epoch=33_val_loss=0.68_AUROC=0.82.ckpt',
#  'MCF-7_CTCF_shuffled_CV-1_20250523_10:09_epoch=38_val_loss=0.32_AUROC=0.96.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-4_20250523_11:25_epoch=15_val_loss=0.67_AUROC=0.67.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-1_20250523_11:29_epoch=17_val_loss=0.68_AUROC=0.68.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-3_20250523_11:37_epoch=44_val_loss=0.34_AUROC=0.95.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-2_20250523_11:16_epoch=00_val_loss=0.69_AUROC=0.50.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-0_20250523_12:51_epoch=12_val_loss=0.51_AUROC=0.80.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-5_20250523_11:33_epoch=14_val_loss=0.72_AUROC=0.69.ckpt',
#  'GM12878_CTCF_neighbors_CV-2_20250523_12:39_epoch=18_val_loss=0.20_AUROC=0.98.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-3_20250523_11:53_epoch=11_val_loss=0.23_AUROC=0.98.ckpt',
#  'MCF-7_CTCF_dinucl-sampled_CV-0_20250523_09:56_epoch=13_val_loss=0.49_AUROC=0.85.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-2_20250523_10:33_epoch=25_val_loss=0.72_AUROC=0.69.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-5_20250523_11:49_epoch=16_val_loss=0.66_AUROC=0.66.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-2_20250523_10:04_epoch=12_val_loss=0.62_AUROC=0.72.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-3_20250523_10:04_epoch=13_val_loss=0.64_AUROC=0.75.ckpt',
#  'GM12878_CTCF_shuffled_CV-3_20250523_12:13_epoch=11_val_loss=0.28_AUROC=0.99.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-5_20250523_11:01_epoch=16_val_loss=0.64_AUROC=0.69.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-3_20250523_11:32_epoch=14_val_loss=0.73_AUROC=0.58.ckpt',
#  'GM12878_CTCF_shuffled_CV-0_20250523_12:08_epoch=28_val_loss=0.11_AUROC=0.99.ckpt',
#  'MCF-7_CTCF_shuffled_CV-2_20250523_10:09_epoch=19_val_loss=0.44_AUROC=0.95.ckpt',
#  'MCF-7_CTCF_dinucl-sampled_CV-1_20250523_09:56_epoch=13_val_loss=0.48_AUROC=0.86.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-4_20250523_11:55_epoch=31_val_loss=0.42_AUROC=0.98.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-5_20250523_12:57_epoch=11_val_loss=0.41_AUROC=0.89.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-0_20250523_11:15_epoch=27_val_loss=0.69_AUROC=0.60.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-0_20250523_11:07_epoch=28_val_loss=0.24_AUROC=0.97.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-3_20250523_11:19_epoch=15_val_loss=0.68_AUROC=0.60.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-4_20250523_10:51_epoch=15_val_loss=0.67_AUROC=0.63.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-0_20250523_10:24_epoch=23_val_loss=0.63_AUROC=0.72.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-2_20250523_11:24_epoch=20_val_loss=0.69_AUROC=0.67.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-1_20250523_11:02_epoch=18_val_loss=0.65_AUROC=0.69.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-4_20250523_12:55_epoch=12_val_loss=0.47_AUROC=0.87.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-2_20250523_10:48_epoch=27_val_loss=0.67_AUROC=0.61.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-4_20250523_13:04_epoch=13_val_loss=0.55_AUROC=0.81.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-2_20250523_10:41_epoch=35_val_loss=0.37_AUROC=0.92.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-3_20250523_12:02_epoch=15_val_loss=0.32_AUROC=0.94.ckpt',
#  'GM12878_CTCF_shuffled_CV-4_20250523_12:18_epoch=18_val_loss=0.27_AUROC=0.99.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-1_20250523_10:40_epoch=52_val_loss=0.49_AUROC=0.94.ckpt',
#  'GM12878_CTCF_neighbors_CV-3_20250523_12:41_epoch=33_val_loss=0.37_AUROC=0.97.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-0_20250523_11:34_epoch=35_val_loss=0.41_AUROC=0.94.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-2_20250523_12:00_epoch=59_val_loss=0.42_AUROC=0.96.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-5_20250523_11:58_epoch=13_val_loss=0.17_AUROC=0.98.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-1_20250523_10:57_epoch=08_val_loss=0.70_AUROC=0.66.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-1_20250523_12:00_epoch=17_val_loss=0.27_AUROC=0.96.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-2_20250523_11:09_epoch=41_val_loss=0.24_AUROC=0.97.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-1_20250523_10:32_epoch=36_val_loss=0.68_AUROC=0.67.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-0_20250523_11:22_epoch=22_val_loss=0.63_AUROC=0.71.ckpt',
#  'MCF-7_CTCF_shuffled_CV-0_20250523_10:07_epoch=16_val_loss=0.44_AUROC=0.95.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-4_20250523_11:11_epoch=29_val_loss=0.26_AUROC=0.96.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-3_20250523_11:25_epoch=22_val_loss=0.63_AUROC=0.70.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-2_20250523_11:46_epoch=24_val_loss=0.67_AUROC=0.63.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-5_20250523_10:53_epoch=16_val_loss=0.72_AUROC=0.66.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-1_20250523_11:09_epoch=44_val_loss=0.35_AUROC=0.96.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-1_20250523_11:52_epoch=26_val_loss=0.39_AUROC=0.97.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-0_20250523_11:43_epoch=20_val_loss=0.67_AUROC=0.63.ckpt',
#  'GM12878_CTCF_neighbors_CV-1_20250523_12:37_epoch=17_val_loss=0.25_AUROC=0.97.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-4_20250523_10:36_epoch=12_val_loss=0.64_AUROC=0.72.ckpt',
#  'MCF-7_CTCF_dinucl-sampled_CV-2_20250523_09:56_epoch=14_val_loss=0.49_AUROC=0.84.ckpt',
#  'MCF-7_TCF7L2_neighbors_CV-1_20250523_10:47_epoch=16_val_loss=0.70_AUROC=0.64.ckpt',
#  'GM12878_CTCF_neighbors_CV-0_20250523_12:34_epoch=21_val_loss=0.48_AUROC=0.97.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-5_20250523_11:28_epoch=18_val_loss=0.69_AUROC=0.69.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-1_20250523_11:43_epoch=20_val_loss=0.68_AUROC=0.60.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-2_20250523_11:03_epoch=18_val_loss=0.64_AUROC=0.69.ckpt',
#  'MCF-7_TCF7L2_dinucl-shuffled_CV-5_20250523_10:37_epoch=19_val_loss=0.67_AUROC=0.65.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-sampled_CV-1_20250523_11:24_epoch=22_val_loss=0.64_AUROC=0.70.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-5_20250523_11:20_epoch=12_val_loss=0.67_AUROC=0.64.ckpt',
#  'GM12878_CTCF_dinucl-shuffled_CV-5_20250523_12:07_epoch=14_val_loss=0.45_AUROC=0.90.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-4_20250523_10:05_epoch=12_val_loss=0.49_AUROC=0.85.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-2_20250523_11:30_epoch=10_val_loss=0.73_AUROC=0.54.ckpt',
#  'MCF-7_GATA3_(SC-268)_dinucl-shuffled_CV-4_20250523_11:33_epoch=17_val_loss=0.65_AUROC=0.67.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-4_20250523_10:44_epoch=25_val_loss=0.50_AUROC=0.91.ckpt',
#  'MCF-7_CTCF_neighbors_CV-0_20250523_10:14_epoch=12_val_loss=0.47_AUROC=0.86.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-0_20250523_10:55_epoch=13_val_loss=0.65_AUROC=0.70.ckpt',
#  'MCF-7_CTCF_shuffled_CV-5_20250523_10:14_epoch=26_val_loss=0.21_AUROC=0.97.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-1_20250523_10:26_epoch=32_val_loss=0.61_AUROC=0.73.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-shuffled_CV-3_20250523_13:02_epoch=10_val_loss=0.63_AUROC=0.76.ckpt',
#  'GM12878_YY1_(SC-281)_dinucl-sampled_CV-2_20250523_12:55_epoch=10_val_loss=0.44_AUROC=0.88.ckpt',
#  'MCF-7_CTCF_shuffled_CV-3_20250523_10:10_epoch=23_val_loss=0.22_AUROC=0.97.ckpt',
#  'MCF-7_GATA3_(SC-268)_shuffled_CV-2_20250523_11:37_epoch=41_val_loss=0.42_AUROC=0.94.ckpt',
#  'MCF-7_CTCF_dinucl-sampled_CV-5_20250523_10:01_epoch=12_val_loss=0.50_AUROC=0.87.ckpt',
#  'GM12878_CTCF_neighbors_CV-5_20250523_12:47_epoch=22_val_loss=0.33_AUROC=0.97.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-2_20250523_10:26_epoch=20_val_loss=0.62_AUROC=0.73.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-4_20250523_10:28_epoch=19_val_loss=0.62_AUROC=0.72.ckpt',
#  'MCF-7_ZNF217_shuffled_CV-3_20250523_11:10_epoch=39_val_loss=0.64_AUROC=0.95.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-3_20250523_10:28_epoch=19_val_loss=0.64_AUROC=0.71.ckpt',
#  'MCF-7_CTCF_neighbors_CV-1_20250523_10:15_epoch=18_val_loss=0.47_AUROC=0.86.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-5_20250523_10:45_epoch=59_val_loss=0.38_AUROC=0.96.ckpt',
#  'MCF-7_TCF7L2_dinucl-sampled_CV-5_20250523_10:30_epoch=12_val_loss=0.68_AUROC=0.66.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-5_20250523_11:06_epoch=12_val_loss=0.62_AUROC=0.72.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-4_20250523_10:59_epoch=15_val_loss=0.63_AUROC=0.70.ckpt',
#  'MCF-7_TCF7L2_shuffled_CV-0_20250523_10:38_epoch=15_val_loss=0.44_AUROC=0.94.ckpt',
#  'MCF-7_CTCF_neighbors_CV-3_20250523_10:20_epoch=11_val_loss=0.45_AUROC=0.88.ckpt',
#  'MCF-7_ZNF217_dinucl-sampled_CV-3_20250523_10:58_epoch=19_val_loss=0.63_AUROC=0.71.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-4_20250523_11:19_epoch=12_val_loss=0.68_AUROC=0.60.ckpt',
#  'MCF-7_GATA3_(SC-268)_neighbors_CV-3_20250523_11:47_epoch=24_val_loss=0.66_AUROC=0.66.ckpt',
#  'MCF-7_ZNF217_dinucl-shuffled_CV-0_20250523_11:02_epoch=19_val_loss=0.63_AUROC=0.71.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-0_20250523_11:51_epoch=15_val_loss=0.19_AUROC=0.98.ckpt',
#  'GM12878_CTCF_dinucl-sampled_CV-2_20250523_11:53_epoch=20_val_loss=0.56_AUROC=0.97.ckpt',
#  'GM12878_CTCF_shuffled_CV-2_20250523_12:11_epoch=48_val_loss=0.29_AUROC=0.99.ckpt',
#  'MCF-7_ZNF217_neighbors_CV-1_20250523_11:15_epoch=18_val_loss=0.71_AUROC=0.60.ckpt',
#  'MCF-7_CTCF_dinucl-shuffled_CV-0_20250523_10:02_epoch=12_val_loss=0.58_AUROC=0.78.ckpt']

# %%
df = get_current_df()

# %%
df_mcf7 = df[df['Cell Type'] == 'MCF-7']
model_combinations_df_mcf7 = model_combinations_df[model_combinations_df['Cell Type'] == 'MCF-7']

# %%
df_mcf7
# Out:
#     Cell Type              TF Negative Sampling Mode Cross Val Fold      Date  \
# 0       MCF-7            CTCF         dinucl-sampled           CV-3  20250523
# 3       MCF-7          ZNF217         dinucl-sampled           CV-2  20250523
# 4       MCF-7          TCF7L2        dinucl-shuffled           CV-3  20250523
# 5       MCF-7          TCF7L2        dinucl-shuffled           CV-0  20250523
# 6       MCF-7            CTCF         dinucl-sampled           CV-4  20250523
# ..        ...             ...                    ...            ...       ...
# 125     MCF-7          ZNF217              neighbors           CV-4  20250523
# 126     MCF-7  GATA3_(SC-268)              neighbors           CV-3  20250523
# 127     MCF-7          ZNF217        dinucl-shuffled           CV-0  20250523
# 131     MCF-7          ZNF217              neighbors           CV-1  20250523
# 132     MCF-7            CTCF        dinucl-shuffled           CV-0  20250523
#
#       Time
# 0    09:56
# 3    10:58
# 4    10:36
# 5    10:32
# 6    10:01
# ..     ...
# 125  11:19
# 126  11:47
# 127  11:02
# 131  11:15
# 132  10:02
#
# [96 rows x 6 columns]

# %%
model_combinations_df_mcf7
# Out:
#    Cell Type              TF Negative Sampling Mode  Cross Val Fold
# 0      MCF-7            CTCF         dinucl_sampled               0
# 1      MCF-7            CTCF         dinucl_sampled               1
# 2      MCF-7            CTCF         dinucl_sampled               2
# 3      MCF-7            CTCF         dinucl_sampled               3
# 4      MCF-7            CTCF         dinucl_sampled               4
# ..       ...             ...                    ...             ...
# 91     MCF-7  GATA3_(SC-268)              neighbors               1
# 92     MCF-7  GATA3_(SC-268)              neighbors               2
# 93     MCF-7  GATA3_(SC-268)              neighbors               3
# 94     MCF-7  GATA3_(SC-268)              neighbors               4
# 95     MCF-7  GATA3_(SC-268)              neighbors               5
#
# [96 rows x 4 columns]

# %%
model_combinations_df_mcf7
# Out:
#    Cell Type              TF Negative Sampling Mode  Cross Val Fold
# 0      MCF-7            CTCF         dinucl_sampled               0
# 1      MCF-7            CTCF         dinucl_sampled               1
# 2      MCF-7            CTCF         dinucl_sampled               2
# 3      MCF-7            CTCF         dinucl_sampled               3
# 4      MCF-7            CTCF         dinucl_sampled               4
# ..       ...             ...                    ...             ...
# 91     MCF-7  GATA3_(SC-268)              neighbors               1
# 92     MCF-7  GATA3_(SC-268)              neighbors               2
# 93     MCF-7  GATA3_(SC-268)              neighbors               3
# 94     MCF-7  GATA3_(SC-268)              neighbors               4
# 95     MCF-7  GATA3_(SC-268)              neighbors               5
#
# [96 rows x 4 columns]

# %%
    while True:
        os.system('clear')
        df = get_current_df()
        print("Model Training Progress Monitor")
        print("=====================================")
        print("Tracking:", output_folder)
        print("Last Update:", time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
        # Combine 'Date' and 'Time' columns into a single datetime column and find the earliest and latest timepoints
        datetimes = pd.to_datetime(df['Date'] + ' ' + df['Time'])
        earliest_timepoint = datetimes.min()
        latest_timepoint = datetimes.max()
        time_difference = latest_timepoint - earliest_timepoint
        print("Approximate Running Time:", time_difference)
        print("=====================================")
        completed = len(df)
        total = len(model_combinations_df)
        print(f"Overall Progress: {completed}/{total} ({completed/total:.2%})")
        with tqdm(total=total, desc="Overall Progress") as pbar:
            pbar.update(completed)

        celltype_totals = model_combinations_df['Cell Type'].value_counts().to_dict()
        celltype_completions = df['Cell Type'].value_counts().to_dict()
        for celltype in celltype_totals:
            total = celltype_totals[celltype]
            completed = celltype_completions.get(celltype, 0)
            print(f"{celltype} Progress: {completed}/{total} ({completed/total:.2%})")
            with tqdm(total=total, desc=f"{celltype} Progress") as pbar:
                pbar.update(completed)
        time.sleep(60)
