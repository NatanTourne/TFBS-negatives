# %%
import pandas as pd
import os
import shutil


ChIP_folder = "/data/home/natant/Negatives/Data/Encode690/ENCODE_hg38"
metadata_file = "/data/home/natant/Negatives/Data/Encode690/ENCODE_hg38/metadata.csv"
metadata_file_maxatac = "/data/home/natant/Negatives/Data/maxATAC/maxatac_chip.csv"

# %%
# Load the metadata files
metadata_df = pd.read_csv(metadata_file)
metadata_maxatac_df = pd.read_csv(metadata_file_maxatac, sep='\t')

# Function to extract text before the first underscore, remove "-", and make it lowercase
def extract_tf_name(tf):
    return tf.split('_')[0].replace('-', '').lower()

# Apply the function to both metadata_maxatac_df and df
metadata_maxatac_df["tf_base"] = metadata_maxatac_df["tf"].apply(extract_tf_name)
metadata_df["antibody_base"] = metadata_df["antibody"].apply(extract_tf_name)

# Get unique base TFs from metadata_maxatac_df and df
maxatac_tfs_base = set(metadata_maxatac_df["tf_base"].unique())
df_tfs_base = set(metadata_df["antibody_base"].unique())

# Find common base TFs
common_tfs_base = maxatac_tfs_base.intersection(df_tfs_base)

# Find unique base TFs in metadata_maxatac_df
unique_maxatac_tfs_base = maxatac_tfs_base - df_tfs_base

# Find unique base TFs in df
unique_df_tfs_base = df_tfs_base - maxatac_tfs_base

# Print the results
print(f"Number of common base TFs: {len(common_tfs_base)}")
print(f"Number of unique base TFs in metadata_maxatac_df: {len(unique_maxatac_tfs_base)}")
print(f"Number of unique base TFs in df: {len(unique_df_tfs_base)}")

# Optionally, print the unique base TFs
print(f"Unique base TFs in metadata_maxatac_df: {unique_maxatac_tfs_base}")
print(f"Unique base TFs in df: {unique_df_tfs_base}")

# Create a list to store the matched TFs
matched_tfs_list = []
for tf_base in common_tfs_base:
    maxatac_tf = metadata_maxatac_df[metadata_maxatac_df["tf_base"] == tf_base]["tf"].values[0]
    df_tf = metadata_df[metadata_df["antibody_base"] == tf_base]["antibody"].values[0]
    matched_tfs_list.append({"maxatac_tf": maxatac_tf, "df_tf": df_tf})

# Convert the list to a DataFrame
matched_tfs = pd.DataFrame(matched_tfs_list)

# Display the matched TFs
print(matched_tfs)
# Out:
# Number of common base TFs: 60
# Number of unique base TFs in metadata_maxatac_df: 67
# Number of unique base TFs in df: 110
# Unique base TFs in metadata_maxatac_df: {'atf7', 'znf687', 'crem', 'arnt', 'lef1', 'znf592', 'tcf7', 'junb', 'nr2f1', 'myb', 'gabpa', 'nr2c2', 'smad5', 'e4f1', 'zhx2', 'zscan29', 'nfe2l2', 'foxp1', 'runx1', 'skil', 'pax8', 'gata4', 'mnt', 'rela', 'srebf1', 'cbx2', 'sox6', 'etv6', 'ash1l', 'zbed1', 'znf207', 'kmt2a', 'znf569', 'znf384', 'hes1', 'mbd2', 'nkrf', 'zfx', 'zbtb40', 'esrra', 'klf5', 'nr2c1', 'spi1', 'jun', 'cebpz', 'myc', 'znf24', 'elf4', 'neurod1', 'e2f8', 'srebf2', 'fos', 'rfx1', 'foxk2', 'nfatc3', 'rest', 'nfia', 'smad1', 'ybx1', 'zbtb11', 'znf282', 'gatad2b', 'cux1', 'znf407', 'nr2f6', 'nfxl1', 'pknox1'}
# Unique base TFs in df: {'nfkb', 'grp20', 'sin3ak20', 'gata2', 'mta3', 'nrsf', 'gr', 'egfphdac8', 'hdac1', 'cmyc', 'sap30', 'ubf', 'tr4', 'pu.1', 'p300', 'sp4', 'foxp2', 'brf1', 'rpc155', 'irf4', 'pou2f2', 'baf155', 'bdp1', 'pol3', 'egfpjunb', 'jarid1a', 'kap1', 'mbd4', 'ubtf', 'tblr1', 'gata1', 'hdac2', 'mef2c', 'ctcfl', 'corest', 'chd2', 'ap2gamma', 'plu1', 'irf1', 'ctbp2', 'tal1', 'sp2', 'gtf2b', 'pol24h8', 'ebf1', 'hae2f1', 'tcf3', 'elk4', 'taf7', 'gabp', 'rbbp5', 'pol2(phosphos2)', 'rad21', 'stat3', 'ini1', 'trim28', 'egfpfos', 'suz12', 'egfpjund', 'bcl11a', 'runx3', 'hnf4g', 'hmgn3', 'sin3a', 'eralpha', 'brg1', 'nfe2', 'e2f6', 'baf170', 'hdac6', 'pgc1a', 'phf8', 'prdm1', 'pol2', 'foxa2', 'smc3', 'bcl3', 'tfiiic110', 'znf263', 'taf1', 'erra', 'whip', 'e2f4', 'hnf4a', 'cfos', 'egfpgata2', 'chd1', 'ccnt2', 'nfatc1', 'ap2alpha', 'nelfe', 'pml', 'sirt6', 'pax5c20', 'srebp1', 'thap1', 'ezh2', 'stat1', 'brf2', 'gtf2f1', 'pax5n19', 'e2f1', 'brca1', 'bclaf1', 'pol2(b)', 'cbx3', 'batf', 'spt20', 'cjun', 'stat2'}
#    maxatac_tf                df_tf
# 0        ZZZ3                 ZZZ3
# 1        NRF1                 Nrf1
# 2        SIX5                 SIX5
# 3         YY1         YY1_(SC-281)
# 4         SP1                  SP1
# 5       IKZF1   IKZF1_(IkN)_(UCLA)
# 6       NANOG     NANOG_(SC-33759)
# 7     ZKSCAN1  ZKSCAN1_(HPA006672)
# 8      ZBTB7A    ZBTB7A_(SC-34508)
# 9      SETDB1               SETDB1
# 10       NFYB                NF-YB
# 11       MXI1        Mxi1_(AF4185)
# 12       PBX3                 Pbx3
# 13       ELK1        ELK1_(1277-1)
# 14       ATF2      ATF2_(SC-81188)
# 15      CEBPD       CEBPD_(SC-636)
# 16       USF2                 USF2
# 17       ATF3                 ATF3
# 18       ATF1        ATF1_(06-325)
# 19       NFIC      NFIC_(SC-81335)
# 20      TCF12                TCF12
# 21       USF1                USF-1
# 22        TBP                  TBP
# 23     ARID3A   ARID3A_(NB100-279)
# 24       RXRA                 RXRA
# 25       JUND                 JunD
# 26      CREB1       CREB1_(SC-240)
# 27      NR2F2    NR2F2_(SC-271940)
# 28     ZNF217               ZNF217
# 29     TCF7L2               TCF7L2
# 30       ETS1                 ETS1
# 31       ZEB1      ZEB1_(SC-25388)
# 32        SRF                  SRF
# 33       MAFF         MafF_(M8194)
# 34     POU5F1     POU5F1_(SC-9081)
# 35     ZNF274               ZNF274
# 36      GATA3       GATA3_(SC-268)
# 37     ZNF143  Znf143_(16618-1-AP)
# 38       NFYA                NF-YA
# 39      MEF2A                MEF2A
# 40       HSF1                 HSF1
# 41        MAX                  Max
# 42      CEBPB       CEBPB_(SC-150)
# 43      FOXM1       FOXM1_(SC-502)
# 44      TEAD4    TEAD4_(SC-101184)
# 45     ZBTB33               ZBTB33
# 46       IRF3                 IRF3
# 47       MAFK       MafK_(ab50322)
# 48       CTCF                 CTCF
# 49      FOSL1       FOSL1_(SC-183)
# 50      MYBL2     MYBL2_(SC-81192)
# 51       RFX5   RFX5_(200-401-194)
# 52       EGR1                Egr-1
# 53       ELF1        ELF1_(SC-631)
# 54        MAZ        MAZ_(ab85725)
# 55      FOXA1    FOXA1_(SC-101058)
# 56     STAT5A    STAT5A_(SC-74442)
# 57      FOSL2                FOSL2
# 58      BACH1     Bach1_(sc-14700)
# 59    BHLHE40              BHLHE40

# %%
# Function to normalize cell type names by making them lowercase and removing "-"
def normalize_cell_name(cell):
    return cell.replace('-', '').lower()

# Apply the function to both metadata_maxatac_df and df
metadata_maxatac_df["cell_base"] = metadata_maxatac_df["cell"].apply(normalize_cell_name)
metadata_df["cell_base"] = metadata_df["cell"].apply(normalize_cell_name)

# Get unique normalized cell types from metadata_maxatac_df and df
maxatac_cells_base = set(metadata_maxatac_df["cell_base"].unique())
df_cells_base = set(metadata_df["cell_base"].unique())

# Find common normalized cell types
common_cells_base = maxatac_cells_base.intersection(df_cells_base)

# Find unique normalized cell types in metadata_maxatac_df
unique_maxatac_cells_base = maxatac_cells_base - df_cells_base

# Find unique normalized cell types in df
unique_df_cells_base = df_cells_base - maxatac_cells_base

# Print the results
print(f"Number of common cell types: {len(common_cells_base)}")
print(f"Number of unique cell types in metadata_maxatac_df: {len(unique_maxatac_cells_base)}")
print(f"Number of unique cell types in df: {len(unique_df_cells_base)}")

# Optionally, print the unique cell types
print(f"Unique cell types in metadata_maxatac_df: {unique_maxatac_cells_base}")
print(f"Unique cell types in df: {unique_df_cells_base}")
# Create a list to store the matched cell types
matched_cells_list = []
for cell_base in common_cells_base:
    maxatac_cell = metadata_maxatac_df[metadata_maxatac_df["cell_base"] == cell_base]["cell"].values[0]
    df_cell = metadata_df[metadata_df["cell_base"] == cell_base]["cell"].values[0]
    matched_cells_list.append({"maxatac_cell": maxatac_cell, "df_cell": df_cell})

# Convert the list to a DataFrame
matched_cells = pd.DataFrame(matched_cells_list)

# Display the matched cell types
print(matched_cells)

# Get the original names of the unmatched cell types in metadata_maxatac_df
unmatched_maxatac_cells = metadata_maxatac_df[metadata_maxatac_df["cell_base"].isin(unique_maxatac_cells_base)]["cell"].unique()

# Get the original names of the unmatched cell types in df
unmatched_df_cells = metadata_df[metadata_df["cell_base"].isin(unique_df_cells_base)]["cell"].unique()

# Print the results
print(f"Unmatched cell types in metadata_maxatac_df: {unmatched_maxatac_cells}")
print(f"Unmatched cell types in df: {unmatched_df_cells}")
# Out:
# Number of common cell types: 10
# Number of unique cell types in metadata_maxatac_df: 10
# Number of unique cell types in df: 81
# Unique cell types in metadata_maxatac_df: {'lovo', 'thp1', 'jurkat', 'rpmi8402', 'hela', 'wa09', 'gm23338', 'hek293t', 'mv411', 'pc3'}
# Unique cell types in df: {'u87', 'hcpepic', 'gm06990', 'hcfaa', 'gm19193', 'u2os', 'ag09319', 'gm12864', 'gm10847', 'gliobla', 'sknsh_ra', 'hsmm', 'ag09309', 'helas3', 'pbde', 'nha', 'ag04449', 'hl60', 'caco2', 'pfsk1', 'hpf', 'hff', 'be2_c', 'dnd41', 'huvec', 'gm12891', 'aoaf', 'hbmec', 'hmf', 'gm18505', 'gm19240', 'gm12873', 'hrpepic', 'hasp', 'gm12875', 'gm19099', 'sknmc', 'ecc1', 'nhek', 'saec', 'hre', 'gm12865', 'ag10803', 'ag04450', 'pbdefetal', 'progfib', 'hac', 'nb4', 'nhlf', 'gm18951', 'gm19239', 'fibrobl', 'hsmmtube', 'gm15510', 'hpaf', 'gm12892', 'mcf10aersrc', 'h1hesc', 'nhdfneo', 'gm19238', 'gm12872', 'rptec', 'nt2d1', 'wi38', 'gm12874', 'gm12801', 'nhdfad', 'osteobl', 'hvmf', 'gm18526', 'hek293trex', 'heepic', 'hmec', 'bj', 'hffmyc', 'gm08714', 'shsy5y', 'hcm', 'raji', 't47d', 'werirb1'}
#   maxatac_cell  df_cell
# 0      GM12878  GM12878
# 1         A549     A549
# 2       HCT116  HCT-116
# 3         K562     K562
# 4        MCF-7    MCF-7
# 5        Panc1   PANC-1
# 6       HEK293   HEK293
# 7       IMR-90    IMR90
# 8      SK-N-SH  SK-N-SH
# 9        HepG2    HepG2
# Unmatched cell types in metadata_maxatac_df: ['GM23338' 'HEK293T' 'WA09' 'PC-3' 'HeLa' 'MV4-11' 'LoVo' 'RPMI-8402'
#  'THP-1' 'Jurkat']
# Unmatched cell types in df: ['Dnd41' 'H1-hESC' 'HeLa-S3' 'HMEC' 'HSMM' 'HSMMtube' 'HUVEC' 'NH-A'
#  'NHDF-Ad' 'NHEK' 'NHLF' 'Osteobl' 'ECC-1' 'GM12891' 'GM12892' 'PFSK-1'
#  'SK-N-MC' 'SK-N-SH_RA' 'T-47D' 'U87' 'GM08714' 'GM10847' 'GM15510'
#  'GM18505' 'GM18526' 'GM18951' 'GM19099' 'GM19193' 'HEK293-T-REx'
#  'MCF10A-Er-Src' 'NB4' 'NT2-D1' 'PBDE' 'PBDEFetal' 'Raji' 'SH-SY5Y' 'U2OS'
#  'Fibrobl' 'Gliobla' 'GM19238' 'GM19239' 'GM19240' 'ProgFib' 'AG04449'
#  'AG04450' 'AG09309' 'AG09319' 'AG10803' 'AoAF' 'BE2_C' 'BJ' 'Caco-2'
#  'GM06990' 'GM12801' 'GM12864' 'GM12865' 'GM12872' 'GM12873' 'GM12874'
#  'GM12875' 'HAc' 'HA-sp' 'HBMEC' 'HCFaa' 'HCM' 'HCPEpiC' 'HEEpiC' 'HFF'
#  'HFF-Myc' 'HL-60' 'HMF' 'HPAF' 'HPF' 'HRE' 'HRPEpiC' 'HVMF' 'NHDF-neo'
#  'RPTEC' 'SAEC' 'WERI-Rb-1' 'WI-38']

# %%
# Filter df to include only matched cells
matched_cells_set = set(matched_cells["df_cell"])
df_filtered_cells = metadata_df[metadata_df["cell"].isin(matched_cells_set)]

# Filter df_filtered_cells to include only matched TFs
matched_tfs_set = set(matched_tfs["df_tf"])
df_filtered = df_filtered_cells[df_filtered_cells["antibody"].isin(matched_tfs_set)]

# Display the filtered dataframe
df_filtered
# Add columns for corresponding celltype and tf name in the maxatac dataset
df_filtered = df_filtered.merge(matched_cells, left_on='cell', right_on='df_cell', how='left')
df_filtered = df_filtered.merge(matched_tfs, left_on='antibody', right_on='df_tf', how='left')

# %%
df_filtered_cells
# Out:
#       project    lab               composite dataType   view     cell  \
# 2    wgEncode  Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks  GM12878
# 3    wgEncode  Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks  GM12878
# 12   wgEncode  Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    HepG2
# 13   wgEncode  Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    HepG2
# 23   wgEncode  Broad  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     K562
# ..        ...    ...                     ...      ...    ...      ...
# 663  wgEncode     UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks  HCT-116
# 665  wgEncode     UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks   HEK293
# 667  wgEncode     UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    HepG2
# 679  wgEncode     UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks     K562
# 680  wgEncode     UW  wgEncodeAwgTfbsUniform  ChipSeq  Peaks    MCF-7
#
#     treatment          antibody control             dataVersion  ...  \
# 2         NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 3         NaN      EZH2_(39875)     std  ENCODE Mar 2012 Freeze  ...
# 12        NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 13        NaN      EZH2_(39875)     std  ENCODE Mar 2012 Freeze  ...
# 23        NaN  CHD1_(A301-218A)     std  ENCODE Mar 2012 Freeze  ...
# ..        ...               ...     ...                     ...  ...
# 663       NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 665       NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 667       NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 679       NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
# 680       NaN              CTCF     std  ENCODE Mar 2012 Freeze  ...
#
#             controlId  quality                                  tableName  \
# 2    wgEncodeEH000037     good       wgEncodeAwgTfbsBroadGm12878CtcfUniPk
# 3    wgEncodeEH000037     good  wgEncodeAwgTfbsBroadGm12878Ezh239875UniPk
# 12   wgEncodeEH000084     good         wgEncodeAwgTfbsBroadHepg2CtcfUniPk
# 13   wgEncodeEH000084  caution    wgEncodeAwgTfbsBroadHepg2Ezh239875UniPk
# 23   wgEncodeEH000052     good  wgEncodeAwgTfbsBroadK562Chd1a301218aUniPk
# ..                ...      ...                                        ...
# 663  wgEncodeEH000950     good           wgEncodeAwgTfbsUwHct116CtcfUniPk
# 665  wgEncodeEH000464     good           wgEncodeAwgTfbsUwHek293CtcfUniPk
# 667  wgEncodeEH000470     good            wgEncodeAwgTfbsUwHepg2CtcfUniPk
# 679  wgEncodeEH000471     good             wgEncodeAwgTfbsUwK562CtcfUniPk
# 680  wgEncodeEH000968     good             wgEncodeAwgTfbsUwMcf7CtcfUniPk
#
#            type                            md5sum   size  \
# 2    narrowPeak  fef0af7fe1e724159e665085da53efb1   982K
# 3    narrowPeak  9a87661953cb6419847abd00599f0a30    66K
# 12   narrowPeak  6f8ab32864e515e0362494a3a8df2b8e   892K
# 13   narrowPeak  5e3ba666537059025883191074765280    85K
# 23   narrowPeak  a16380fc02b67d668afe29a58a2d429f   227K
# ..          ...                               ...    ...
# 663  narrowPeak  5353919b8dec58898d42391ed013ed3b  1006K
# 665  narrowPeak  85054a5025553ab029c7eb16c94dcbc4   1.1M
# 667  narrowPeak  3fdf2bfeeb9bf469510d615efec560ae   905K
# 679  narrowPeak  365af2fdea48c046dafad14b73f69b5d   850K
# 680  narrowPeak  5cef2172388928830a1151f06efdd161   1.2M
#
#                                           old_filename  \
# 2    wgEncodeAwgTfbsBroadGm12878CtcfUniPk.narrowPea...
# 3    wgEncodeAwgTfbsBroadGm12878Ezh239875UniPk.narr...
# 12    wgEncodeAwgTfbsBroadHepg2CtcfUniPk.narrowPeak.gz
# 13   wgEncodeAwgTfbsBroadHepg2Ezh239875UniPk.narrow...
# 23   wgEncodeAwgTfbsBroadK562Chd1a301218aUniPk.narr...
# ..                                                 ...
# 663     wgEncodeAwgTfbsUwHct116CtcfUniPk.narrowPeak.gz
# 665     wgEncodeAwgTfbsUwHek293CtcfUniPk.narrowPeak.gz
# 667      wgEncodeAwgTfbsUwHepg2CtcfUniPk.narrowPeak.gz
# 679       wgEncodeAwgTfbsUwK562CtcfUniPk.narrowPeak.gz
# 680       wgEncodeAwgTfbsUwMcf7CtcfUniPk.narrowPeak.gz
#
#                                     filename antibody_base cell_base
# 2             GM12878__CTCF__None.narrowPeak          ctcf   gm12878
# 3     GM12878__EZH2_(39875)__None.narrowPeak          ezh2   gm12878
# 12              HepG2__CTCF__None.narrowPeak          ctcf     hepg2
# 13      HepG2__EZH2_(39875)__None.narrowPeak          ezh2     hepg2
# 23   K562__CHD1_(A301-218A)__None.narrowPeak          chd1      k562
# ..                                       ...           ...       ...
# 663           HCT-116__CTCF__None.narrowPeak          ctcf    hct116
# 665            HEK293__CTCF__None.narrowPeak          ctcf    hek293
# 667             HepG2__CTCF__None.narrowPeak          ctcf     hepg2
# 679              K562__CTCF__None.narrowPeak          ctcf      k562
# 680             MCF-7__CTCF__None.narrowPeak          ctcf      mcf7
#
# [395 rows x 21 columns]

# %%
# Write df_filtered to the output folder as meta.csv
meta_output_path = os.path.join(output_folder, "metadata.csv")
df_filtered.to_csv(meta_output_path, sep='\t', index=False)
